# %% [markdown]
# ## Exploratory Data Analysis of Supermarket Store Branches

# %%
# Import the necessary Modules/Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataframe file
df = pd.read_csv('/content/drive/MyDrive/PYTHON PROJECTS/Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# ### Data Inspection, Cleaning and Manipulation

# %%
# Check Data Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# Check for Null/Empty Values.
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
# Define functions
def convert_to_string(data):
  '''This function converts any value to string dtype.'''
  return f'Store Code {data}'
def convert_to_string1(data):
  '''This function converts any value to string dtype.'''
  return f'Store Area Code {data}'

# %%
# Create a new column called 'Store_Code'.
df['Store_Code'] = df['Store ID '].apply(convert_to_string)
df['Store_Area_Code'] = df['Store_Area'].apply(convert_to_string1)
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 0            1        1659             1961                   530
# 1            2        1461             1752                   210
# 2            3        1340             1609                   720
# 3            4        1451             1748                   620
# 4            5        1770             2111                   450
# ..         ...         ...              ...                   ...
# 891        892        1582             1910                  1080
# 892        893        1387             1663                   850
# 893        894        1200             1436                  1060
# 894        895        1299             1560                   770
# 895        896        1174             1429                  1110
#
#      Store_Sales      Store_Code       Store_Area_Code
# 0          66490    Store Code 1  Store Area Code 1659
# 1          39820    Store Code 2  Store Area Code 1461
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
#  5   Store_Code            896 non-null    object
#  6   Store_Area_Code       896 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 49.1+ KB

# %% [markdown]
# ### Bivariate and Multivariate Analysis

# %%
# Check columns.
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales', 'Store_Code', 'Store_Area_Code'],
#       dtype='object')

# %%
# INSIGHT: Top Ten Store area with the most Sales.
store_area_mostSales = df.loc[:, ['Store_Area_Code',  'Store_Sales']].sort_values('Store_Sales', ascending=False).head(10)
store_area_mostSales
# Out:
#           Store_Area_Code  Store_Sales
# 649  Store Area Code 1989       116320
# 868  Store Area Code 1775       105150
# 432  Store Area Code 1365       102920
# 408  Store Area Code 1303       102310
# 758  Store Area Code 1486       101820
# 557  Store Area Code 1137       101780
# 866  Store Area Code 1565       100900
# 166  Store Area Code 1465        99570
# 692  Store Area Code 1548        99480
# 871  Store Area Code 1800        98260

# %%
# Data visualization
plt.figure(figsize=(7, 5))
plt.title(label='Top Ten Store area with the most Sale')
ax = sns.barplot(data=store_area_mostSales,
            y='Store_Area_Code',
            x='Store_Sales',
            orient= 'h',
            # color='grey'
            )
plt.show()

# %% [markdown]
# #### Observation
# Store Area with code 1989 has the most Sales compared to other store areas.

# %%
# INSIGHT: Top Ten Store area with the most Sales.
store_area_leastSales = df.loc[:, ['Store_Area_Code',  'Store_Sales']].sort_values('Store_Sales', ascending=True).head(10)
store_area_leastSales
# Out:
#           Store_Area_Code  Store_Sales
# 31   Store Area Code 1250        14920
# 852  Store Area Code 1477        16370
# 775  Store Area Code 1537        17670
# 593  Store Area Code 1624        20270
# 352  Store Area Code 1397        21300
# 725  Store Area Code 1445        21470
# 372  Store Area Code 1876        21650
# 277  Store Area Code 1572        21750
# 252  Store Area Code 1583        21830
# 670  Store Area Code 1461        22310

# %%
# Data visualization
plt.figure(figsize=(7, 5))
plt.title(label='Top Ten Store area with the Least Sale')
ax = sns.barplot(data=store_area_leastSales,
            y='Store_Area_Code',
            x='Store_Sales',
            orient= 'h',
            # color='grey'
            )
plt.show()

# %% [markdown]
# #### Observation.
# The Store Area with code 1250 has the least Sales compared to other Store Areas.

# %%
# Show columns
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales', 'Store_Code', 'Store_Area_Code'],
#       dtype='object')

# %%
# INSIGHT: Store Area with the Most Daily Customer Count
most_customer_count = df.loc[:, ['Store_Area_Code', 'Daily_Customer_Count']].sort_values('Daily_Customer_Count', ascending=False).head(4)
most_customer_count
# Out:
#           Store_Area_Code  Daily_Customer_Count
# 848   Store Area Code 919                  1560
# 349  Store Area Code 1886                  1530
# 535  Store Area Code 1057                  1490
# 94   Store Area Code 1921                  1470

# %%
# Data Visualization.
# Set up the Seaborn style
sns.set(style='whitegrid')

# Create a pie chart using Seaborn
plt.figure(figsize=(6, 4))
plt.pie(most_customer_count['Daily_Customer_Count'],
        labels=most_customer_count['Store_Area_Code'],
        colors=sns.color_palette('pastel'),
        autopct='%1.1f%%',
        shadow=True,
        startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Top four Store Area with the Most Daily Customer Count')
plt.show()

# %% [markdown]
# #### Observation
# Store Area with code 919 has the most Daily Count of Customers.
